# %%
#question 1
import numpy as np
import math
a=np.random.rand(10,1)
m=np.mean(a)
m
# Out:
# 0.56649035639615763

# %%
#question 2
b=np.random.rand(20,1)
var=np.var(b)
sd=np.std(b)
print(var)
print(sd)
# Out:
# 0.0592559064527
# 0.243425361153

# %%
#quetsion 3
a=np.random.rand(10,20)
b=np.random.rand(20,25)
res=np.dot(a,b)
print(res)
print(res.sum())
# Out:
# [[ 4.36866062  5.00812687  5.29376116  5.2214596   5.4629804   5.40386616
#    3.89177403  5.63852574  4.72622947  5.1995911   5.52954928  5.38863288
#    4.85036017  6.37888155  5.82222968  4.3947386   5.37287022  5.03571121
#    5.55906689  5.92957501  5.08081654  6.43467809  5.24870002  4.29512939
#    4.89314268]
#  [ 4.54117922  4.11540402  5.09672227  4.65208828  4.34570605  5.23245327
#    3.17716315  5.03612453  4.7594994   4.23863862  3.91695947  4.74963013
#    4.55765447  5.94310396  5.45865854  4.53095522  5.01167474  4.73798275
#    4.76218213  5.94158927  4.58432076  5.81396602  5.12155757  4.43057109
#    4.4848725 ]
#  [ 4.22181402  4.01788276  5.63405101  5.22917671  4.08570884  5.47680345
#    3.64284357  5.01246578  4.39558394  5.01374836  5.04263048  4.613518
#    5.18748946  5.87476601  5.00927216  4.59806473  5.09240923  4.52731788
#    4.57257486  5.3185915   5.51204795  5.36405392  5.14619855  4.97833264
#    4.6643068 ]
# ...

# %%
#question 4
a=np.random.rand(10,1)
res=[]
for row in a:
    b=[]
    for element in row:
        element=1/(1+math.exp((element*-1)))
                                  
        b.append(element)
    res.append(b)
print(res)
# Out:
# [[0.5063965400866747], [0.703909549642186], [0.5996617834948577], [0.5579867142017909], [0.5711273609346573], [0.6222966638076263], [0.5819079778723798], [0.6354432339103454], [0.7105678237841166], [0.6497185437153639]]
