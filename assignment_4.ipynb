# %%
#question 1
import pandas as pd
data={"name":["Amber","Devansh","Sam","Ritesh"],"Age":[20,20,21,21],"Emailid":["ambersinghal98@gmail.com","devansh@gmail.com","abcd@gmail.com","pqr@ymail.com"],
     "Phone no":[9760629329,9760048612,9897648612,9853421236]}
pd.DataFrame(data)
# Out:
#    Age                   Emailid    Phone no     name
# 0   20  ambersinghal98@gmail.com  9760629329    Amber
# 1   20         devansh@gmail.com  9760048612  Devansh
# 2   21            abcd@gmail.com  9897648612      Sam
# 3   21             pqr@ymail.com  9853421236   Ritesh

# %%
#question 2
df=pd.read_csv("weather.csv")
#a
print(df.head(5))
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#b
print(df.head(10))
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
#c
print(df.mean())
print("Standard Deviation is")
print(df.std())
# Out:
# MinTemp             7.265574
# MaxTemp            20.550273
# Rainfall            1.428415
# Evaporation         4.521858
# Sunshine            7.909366
# WindGustSpeed      39.840659
# WindSpeed9am        9.651811
# WindSpeed3pm       17.986339
# Humidity9am        72.035519
# Humidity3pm        44.519126
# Pressure9am      1019.709016
# Pressure3pm      1016.810383
# Cloud9am            3.890710
# Cloud3pm            4.024590
# Temp9am            12.358470
# Temp3pm            19.230874
# RISK_MM             1.428415
# dtype: float64
# Standard Deviation is
# MinTemp           6.025800
# MaxTemp           6.690516
# Rainfall          4.225800
# Evaporation       2.669383
# Sunshine          3.481517
# WindGustSpeed    13.059807
# WindSpeed9am      7.951929
# WindSpeed3pm      8.856997
# Humidity9am      13.137058
# Humidity3pm      16.850947
# Pressure9am       6.686212
# Pressure3pm       6.469422
# Cloud9am          2.956131
# Cloud3pm          2.666268
# ...

# %%
#d
print(df.tail(5))
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
#e
dd=df.iloc[0:265,2:4]
print(dd)
print(dd.mean())
print(dd.std())
# Out:
#      MinTemp  MaxTemp
# 0        8.0     24.3
# 1       14.0     26.9
# 2       13.7     23.4
# 3       13.3     15.5
# 4        7.6     16.1
# 5        6.2     16.9
# 6        6.1     18.2
# 7        8.3     17.0
# 8        8.8     19.5
# 9        8.4     22.8
# 10       9.1     25.2
# 11       8.5     27.3
# 12      10.1     27.9
# 13      12.1     30.9
# 14      10.1     31.2
# 15      12.4     32.1
# 16      13.8     31.2
# 17      11.7     30.0
# 18      12.4     32.3
# 19      15.6     33.4
# 20      15.3     33.4
# 21      16.4     19.4
# 22      12.8     18.5
# 23      12.0     24.3
# 24      15.4     28.4
# 25      15.6     26.9
# 26      13.3     22.2
# 27      12.9     28.0
# 28      15.1     24.3
# 29      13.6     24.1
# ..       ...      ...
# 235      0.9     12.9
# 236      0.8     13.0
# 237      4.3     12.6
# 238      6.3     11.8
# 239      3.5     14.3
# 240     -1.5     14.8
# 241      1.2     16.0
# 242      0.5     15.4
# 243      5.3     11.7
# ...
